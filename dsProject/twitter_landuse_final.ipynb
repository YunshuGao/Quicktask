# %%
import pandas as pd

# %%
import geopandas

# %%
zipfile=r"D:\RA-Tasks\1 Graph neural network_POI\Task1\Process\twitterPoint_final.shp"
df=geopandas.read_file(zipfile)
df.head(5)
# Out:
#    OBJECTID_1  Field1                      created_at        id_str lang  \
# 0           1    1246  Sun May 08 19:42:57 +0000 2016  7.290000e+17   en
# 1           2    1254  Sun May 08 21:20:20 +0000 2016  7.290000e+17   en
# 2           3    3007  Thu May 12 08:04:44 +0000 2016  7.310000e+17   en
# 3           4    3715  Fri May 13 09:07:09 +0000 2016  7.310000e+17   en
# 4           5    4297  Sat May 14 06:37:43 +0000 2016  7.310000e+17   en
#
#          lat         lon                                              text_  \
# 0  22.280900  114.178000  Thanks again Hong Kong <ed><U+00A0><U+00BC><ed...
# 1  22.314882  113.933372  It's that time again! <U+2708><U+FE0F> #HongKo...
# 2  22.280900  114.178000  Static | Behaviour \r\r\r\r\r\r\r\n\r\r\r\r\r\...
# 3  22.339341  114.204015  The Nan lian garden at Diamond Hill in Hong Ko...
# 4  22.313420  114.043526  Advance birthday treat from my sister. <U+2764...
#
# ...

# %%
df1=df[['OBJECTID_1','Field1','created_at','id_str','lang','time_zone','LanduseTyp','geometry']]

# %%
df2=pd.read_csv(r"D:\RA-Tasks\1 Graph neural network_POI\Task1\Process\result_v2.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8992\976543900.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv(r"D:\RA-Tasks\1 Graph neural network_POI\Task1\Process\result_v2.csv")

# %%
df2.rename(columns={ df2.columns[0]: "Field1" }, inplace = True)

# %%
df1.head(5)
# Out:
#    OBJECTID_1  Field1                      created_at        id_str lang  \
# 0           1    1246  Sun May 08 19:42:57 +0000 2016  7.290000e+17   en
# 1           2    1254  Sun May 08 21:20:20 +0000 2016  7.290000e+17   en
# 2           3    3007  Thu May 12 08:04:44 +0000 2016  7.310000e+17   en
# 3           4    3715  Fri May 13 09:07:09 +0000 2016  7.310000e+17   en
# 4           5    4297  Sat May 14 06:37:43 +0000 2016  7.310000e+17   en
#
#    time_zone  LanduseTyp                    geometry
# 0  Abu Dhabi           8  POINT (114.17800 22.28090)
# 1  Abu Dhabi         999  POINT (113.93337 22.31488)
# 2  Abu Dhabi           8  POINT (114.17800 22.28090)
# 3  Abu Dhabi           7  POINT (114.20402 22.33934)
# 4  Abu Dhabi           3  POINT (114.04353 22.31342)

# %%
df2.head(5)
# Out:
#    Field1                      created_at        id_str lang        lat  \
# 0    1246  Sun May 08 19:42:57 +0000 2016  7.290000e+17   en  22.280900
# 1    1254  Sun May 08 21:20:20 +0000 2016  7.290000e+17   en  22.314882
# 2    3007  Thu May 12 08:04:44 +0000 2016  7.310000e+17   en  22.280900
# 3    3715  Fri May 13 09:07:09 +0000 2016  7.310000e+17   en  22.339341
# 4    4297  Sat May 14 06:37:43 +0000 2016  7.310000e+17   en  22.313420
#
#           lon                                               text  time_zone  \
# 0  114.178000  Thanks again Hong Kong <ed><U+00A0><U+00BC><ed...  Abu Dhabi
# 1  113.933372  It's that time again! <U+2708><U+FE0F> #HongKo...  Abu Dhabi
# 2  114.178000  Static | Behaviour \r\r\r\r\r\r\r\r\n\r\r\r\r\...  Abu Dhabi
# 3  114.204015  The Nan lian garden at Diamond Hill in Hong Ko...  Abu Dhabi
# 4  114.043526  Advance birthday treat from my sister. <U+2764...  Abu Dhabi
#
#    truncated                      url  ... user_lang  user_url verified  \
# ...

# %%
df3 = pd.merge(df1, df2, on='Field1', how='inner')

# %%
df3.head(5)
# Out:
#    OBJECTID_1  Field1                    created_at_x      id_str_x lang_x  \
# 0           1    1246  Sun May 08 19:42:57 +0000 2016  7.290000e+17     en
# 1           2    1254  Sun May 08 21:20:20 +0000 2016  7.290000e+17     en
# 2           3    3007  Thu May 12 08:04:44 +0000 2016  7.310000e+17     en
# 3           4    3715  Fri May 13 09:07:09 +0000 2016  7.310000e+17     en
# 4           5    4297  Sat May 14 06:37:43 +0000 2016  7.310000e+17     en
#
#   time_zone_x  LanduseTyp                    geometry  \
# 0   Abu Dhabi           8  POINT (114.17800 22.28090)
# 1   Abu Dhabi         999  POINT (113.93337 22.31488)
# 2   Abu Dhabi           8  POINT (114.17800 22.28090)
# 3   Abu Dhabi           7  POINT (114.20402 22.33934)
# 4   Abu Dhabi           3  POINT (114.04353 22.31342)
#
#                      created_at_y      id_str_y  ... user_lang  user_url  \
# 0  Sun May 08 19:42:57 +0000 2016  7.290000e+17  ...        en       NaN
# ...

# %%
df4=df3[['OBJECTID_1','Field1','LanduseTyp','created_at_x','id_str_x','time_zone_x','geometry','date_thirdprocess','date_hk']]

# %%
df4['date_thirdprocess']= pd.to_datetime(df4['date_thirdprocess'])
df4['date_hk']= pd.to_datetime(df4['date_hk'])
# Out:
# D:\Projetcs\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# D:\Projetcs\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
date_hk_col=pd.DatetimeIndex(df4['date_hk'])

# %%
df4['CreatedWW'] = df4['date_hk'].dt.day_name()
# Out:
# D:\Projetcs\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
df4.head(5)
# Out:
#    OBJECTID_1  Field1 LanduseTyp                    created_at_x  \
# 0           1    1246          8  Sun May 08 19:42:57 +0000 2016
# 1           2    1254        999  Sun May 08 21:20:20 +0000 2016
# 2           3    3007          8  Thu May 12 08:04:44 +0000 2016
# 3           4    3715          7  Fri May 13 09:07:09 +0000 2016
# 4           5    4297          3  Sat May 14 06:37:43 +0000 2016
#
#        id_str_x time_zone_x                    geometry   date_thirdprocess  \
# 0  7.290000e+17   Abu Dhabi  POINT (114.17800 22.28090) 2016-05-08 19:42:00
# 1  7.290000e+17   Abu Dhabi  POINT (113.93337 22.31488) 2016-05-08 21:20:00
# 2  7.310000e+17   Abu Dhabi  POINT (114.17800 22.28090) 2016-05-12 08:04:00
# 3  7.310000e+17   Abu Dhabi  POINT (114.20402 22.33934) 2016-05-13 09:07:00
# 4  7.310000e+17   Abu Dhabi  POINT (114.04353 22.31342) 2016-05-14 06:37:00
#
#               date_hk CreatedWW
# 0 2016-05-08 23:42:00    Sunday
# 1 2016-05-09 01:20:00    Monday
# ...

# %%
import matplotlib.pyplot as plt
df4['id_str_x'].groupby(df4['LanduseTyp']).count()
df4['id_str_x'].groupby(df4['LanduseTyp']).count().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='LanduseTyp'>

# %%
# by year
df4['id_str_x'].groupby([date_hk_col.year,df4['LanduseTyp']]).count()
# Out:
# date_hk  LanduseTyp
# 2016     1               860
#          2             17757
#          3             20095
#          4             18145
#          5               959
#          6               222
#          7             12856
#          8             23067
#          999           42821
# 2017     1              1060
#          2             19003
#          3             24509
#          4             21687
#          5              1275
#          6               261
#          7             14876
#          8             37492
#          999           47200
# 2018     1               641
#          2             13455
#          3             13816
#          4             12881
#          5               906
#          6               201
#          7             13304
#          8             16978
#          999           33299
# Name: id_str_x, dtype: int64

# %%
# by month
df4['id_str_x'].groupby([date_hk_col.month,df4['LanduseTyp']]).count()
# Out:
# date_hk  LanduseTyp
# 1        1               168
#          2              2814
#          3              4022
#          4              3612
#          5               283
#                        ...
# 12       5               265
#          6                52
#          7              3358
#          8              7500
#          999           11692
# Name: id_str_x, Length: 108, dtype: int64

# %%
# by day
df4['id_str_x'].groupby([date_hk_col.day,df4['LanduseTyp']]).count()
# Out:
# date_hk  LanduseTyp
# 1        1               91
#          2             1732
#          3             1907
#          4             1803
#          5              113
#                        ...
# 31       5               57
#          6                8
#          7              635
#          8             1268
#          999           1969
# Name: id_str_x, Length: 279, dtype: int64

# %%
# by hour
df4['id_str_x'].groupby([date_hk_col.hour,df4['LanduseTyp']]).count()
# Out:
# date_hk  LanduseTyp
# 0        1               82
#          2             1869
#          3             2131
#          4             1787
#          5              100
#                        ...
# 23       5               76
#          6               13
#          7              895
#          8             2180
#          999           3677
# Name: id_str_x, Length: 216, dtype: int64

# %%
df4['LanduseTyp'].groupby([date_hk_col.hour]).count().plot()
# Out:
# <AxesSubplot: xlabel='date_hk'>

# %%
df4["LanduseTyp"] = df4["LanduseTyp"].astype("category")
# Out:
# D:\Projetcs\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
df4.dtypes
# Out:
# OBJECTID_1                    int64
# Field1                        int64
# LanduseTyp                 category
# created_at_x                 object
# id_str_x                    float64
# time_zone_x                  object
# geometry                   geometry
# date_thirdprocess    datetime64[ns]
# date_hk              datetime64[ns]
# dtype: object

# %%
df4['LanduseTyp'].groupby([date_hk_col.hour]).count().plot()
# Out:
# <AxesSubplot: xlabel='date_hk'>

# %%
df4['id_str_x'].groupby([date_hk_col.day,df4['LanduseTyp']]).count().plot()
# Out:
# <AxesSubplot: xlabel='date_hk,LanduseTyp'>

# %%
df4['id_str_x'].groupby([df4['LanduseTyp']]).count().plot()
# Out:
# <AxesSubplot: xlabel='LanduseTyp'>

# %%
df4.groupby([date_hk_col.day,df4['LanduseTyp']]).count().plot()
# Out:
# <AxesSubplot: xlabel='date_hk,LanduseTyp'>

# %%
df4['LanduseTyp'].groupby([date_hk_col.day]).count().plot()
# Out:
# <AxesSubplot: xlabel='date_hk'>

# %%
df4['LanduseTyp'=='1'].groupby([date_hk_col.day]).count().plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Projetcs\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File D:\Projetcs\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Projetcs\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df4.loc[df4['LanduseTyp'] == 1]
# Out:
#         OBJECTID_1  Field1 LanduseTyp                    created_at_x  \
# 407000      407001  205223          1  Mon May 08 02:14:02 +0000 2017
# 407001      407002  136704          1  Sat Dec 31 15:37:34 +0000 2016
# 407002      407003   71458          1  Wed Sep 14 12:24:03 +0000 2016
# 407003      407004   76121          1  Fri Sep 23 11:48:36 +0000 2016
# 407004      407005   81234          1  Sun Oct 02 10:36:10 +0000 2016
# ...            ...     ...        ...                             ...
# 409556      409557  357892          1  Sat Jun 23 12:28:25 +0000 2018
# 409557      409558  370820          1  Fri Aug 10 09:32:20 +0000 2018
# 409558      409559  370908          1  Fri Aug 10 13:29:51 +0000 2018
# 409559      409560  390212          1  Wed Oct 17 16:14:02 +0000 2018
# 409560      409561  392377          1  Thu Oct 25 14:00:46 +0000 2018
#
#             id_str_x time_zone_x                    geometry  \
# 407000  8.610000e+17      Alaska  POINT (114.21700 22.55000)
# ...

# %%
df4.loc[df4['LanduseTyp'] == 1].groupby([date_hk_col.day]).count().plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df4.loc[df4['LanduseTyp'] == 1].groupby([date_hk_col.day]).count().plot()
#
# File D:\Projetcs\lib\site-packages\pandas\core\frame.py:8399, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
#    8397 axis = self._get_axis_number(axis)
# -> 8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    8402     axis=axis,
#    8403     level=level,
#    8404     as_index=as_index,
#    8405     sort=sort,
#    8406     group_keys=group_keys,
#    8407     squeeze=squeeze,
#    8408     observed=observed,
#    8409     dropna=dropna,
#    8410 )
#
# ...

# %%
df4.dtypes
# Out:
# OBJECTID_1                    int64
# Field1                        int64
# LanduseTyp                 category
# created_at_x                 object
# id_str_x                    float64
# time_zone_x                  object
# geometry                   geometry
# date_thirdprocess    datetime64[ns]
# date_hk              datetime64[ns]
# dtype: object

# %%
df4.groupby('LanduseTyp').count().plot()
# Out:
# <AxesSubplot: xlabel='LanduseTyp'>

# %%
df4.groupby('LanduseTyp')['id_str_x'].count().plot()
# Out:
# <AxesSubplot: xlabel='LanduseTyp'>

# %%
df5=df4.set_index('date_hk')

# %%
df5.head(5)
# Out:
#                      OBJECTID_1  Field1 LanduseTyp  \
# date_hk
# 2016-05-08 23:42:00           1    1246          8
# 2016-05-09 01:20:00           2    1254        999
# 2016-05-12 12:04:00           3    3007          8
# 2016-05-13 13:07:00           4    3715          7
# 2016-05-14 10:37:00           5    4297          3
#
#                                        created_at_x      id_str_x time_zone_x  \
# date_hk
# 2016-05-08 23:42:00  Sun May 08 19:42:57 +0000 2016  7.290000e+17   Abu Dhabi
# 2016-05-09 01:20:00  Sun May 08 21:20:20 +0000 2016  7.290000e+17   Abu Dhabi
# 2016-05-12 12:04:00  Thu May 12 08:04:44 +0000 2016  7.310000e+17   Abu Dhabi
# 2016-05-13 13:07:00  Fri May 13 09:07:09 +0000 2016  7.310000e+17   Abu Dhabi
# 2016-05-14 10:37:00  Sat May 14 06:37:43 +0000 2016  7.310000e+17   Abu Dhabi
#
#                                        geometry   date_thirdprocess
# date_hk
# 2016-05-08 23:42:00  POINT (114.17800 22.28090) 2016-05-08 19:42:00
# ...

# %%
df5.groupby('LanduseTyp')['id_str_x'].count().plot()
# Out:
# <AxesSubplot: xlabel='LanduseTyp'>

# %%
df6=df4[['LanduseTyp','date_hk']]

# %%
df6.head(5)
# Out:
#   LanduseTyp             date_hk
# 0          8 2016-05-08 23:42:00
# 1        999 2016-05-09 01:20:00
# 2          8 2016-05-12 12:04:00
# 3          7 2016-05-13 13:07:00
# 4          3 2016-05-14 10:37:00

# %%
df6.groupby('LanduseTyp',df6['date_hk']).count().plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df6.groupby('LanduseTyp',df6['date_hk']).count().plot()
#
# File D:\Projetcs\lib\site-packages\pandas\core\frame.py:8397, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8395 if level is None and by is None:
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8397 axis = self._get_axis_number(axis)
#    8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    (...)
#    8409     dropna=dropna,
#    8410 )
#
# File D:\Projetcs\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     550 @final
#     551 @classmethod
#     552 def _get_axis_number(cls, axis: Axis) -> int:
#     553     try:
# --> 554         return cls._AXIS_TO_AXIS_NUMBER[axis]
# ...

# %%
df6=df6.set_index('date_hk')

# %%
df6.head(5)
# Out:
#                     LanduseTyp
# date_hk
# 2016-05-08 23:42:00          8
# 2016-05-09 01:20:00        999
# 2016-05-12 12:04:00          8
# 2016-05-13 13:07:00          7
# 2016-05-14 10:37:00          3

# %%
df6.groupby('LanduseTyp').count().plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df6.groupby('LanduseTyp').count().plot()
#
# File D:\Projetcs\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File D:\Projetcs\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File D:\Projetcs\lib\site-packages\pandas\plotting\_matplotlib\core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
# ...

# %%
df6['Value']=1

# %%
df6.head(5)
# Out:
#                     LanduseTyp  Value
# date_hk
# 2016-05-08 23:42:00          8      1
# 2016-05-09 01:20:00        999      1
# 2016-05-12 12:04:00          8      1
# 2016-05-13 13:07:00          7      1
# 2016-05-14 10:37:00          3      1

# %%
df6.dtypes
# Out:
# LanduseTyp    category
# Value            int64
# dtype: object

# %%
df6.groupby('LanduseTyp')['Value'].count().plot()
# Out:
# <AxesSubplot: xlabel='LanduseTyp'>

# %%
df6.groupby('LanduseTyp',date_hk_col.year)['Value'].count().plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df6.groupby('LanduseTyp',date_hk_col.year)['Value'].count().plot()
#
# File D:\Projetcs\lib\site-packages\pandas\core\frame.py:8397, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8395 if level is None and by is None:
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8397 axis = self._get_axis_number(axis)
#    8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    (...)
#    8409     dropna=dropna,
#    8410 )
#
# File D:\Projetcs\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     550 @final
#     551 @classmethod
#     552 def _get_axis_number(cls, axis: Axis) -> int:
#     553     try:
# --> 554         return cls._AXIS_TO_AXIS_NUMBER[axis]
# ...

# %%
df6.groupby('LanduseTyp')['Value'].plot()
# Out:
# LanduseTyp
# 1      AxesSubplot(0.125,0.2;0.775x0.68)
# 2      AxesSubplot(0.125,0.2;0.775x0.68)
# 3      AxesSubplot(0.125,0.2;0.775x0.68)
# 4      AxesSubplot(0.125,0.2;0.775x0.68)
# 5      AxesSubplot(0.125,0.2;0.775x0.68)
# 6      AxesSubplot(0.125,0.2;0.775x0.68)
# 7      AxesSubplot(0.125,0.2;0.775x0.68)
# 8      AxesSubplot(0.125,0.2;0.775x0.68)
# 999    AxesSubplot(0.125,0.2;0.775x0.68)
# Name: Value, dtype: object

# %%
df6.groupby('LanduseTyp')['Value'].count()
# Out:
# LanduseTyp
# 1        2561
# 2       50215
# 3       58420
# 4       52713
# 5        3140
# 6         684
# 7       41036
# 8       77537
# 999    123320
# Name: Value, dtype: int64

# %%
df7=df4[['LanduseTyp','date_hk']]

# %%
df7.dtypes
# Out:
# LanduseTyp          category
# date_hk       datetime64[ns]
# dtype: object

# %%
df7.groupby('LanduseTyp',date_hk_col.year).count().plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df7.groupby('LanduseTyp',date_hk_col.year).count().plot()
#
# File D:\Projetcs\lib\site-packages\pandas\core\frame.py:8397, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8395 if level is None and by is None:
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8397 axis = self._get_axis_number(axis)
#    8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    (...)
#    8409     dropna=dropna,
#    8410 )
#
# File D:\Projetcs\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     550 @final
#     551 @classmethod
#     552 def _get_axis_number(cls, axis: Axis) -> int:
#     553     try:
# --> 554         return cls._AXIS_TO_AXIS_NUMBER[axis]
# ...

# %%
date_hk_col=pd.DatetimeIndex(df7['date_hk'])

# %%
df7.groupby('LanduseTyp',date_hk_col.year).plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df7.groupby('LanduseTyp',date_hk_col.year).plot()
#
# File D:\Projetcs\lib\site-packages\pandas\core\frame.py:8397, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8395 if level is None and by is None:
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8397 axis = self._get_axis_number(axis)
#    8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    (...)
#    8409     dropna=dropna,
#    8410 )
#
# File D:\Projetcs\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     550 @final
#     551 @classmethod
#     552 def _get_axis_number(cls, axis: Axis) -> int:
#     553     try:
# --> 554         return cls._AXIS_TO_AXIS_NUMBER[axis]
# ...

# %%
df7.dtypes
# Out:
# LanduseTyp          category
# date_hk       datetime64[ns]
# dtype: object

# %%
df7.groupby('LanduseTyp').count().plot()
# Out:
# <AxesSubplot: xlabel='LanduseTyp'>

# %%
df7['LanduseTyp'].groupby([date_hk_col.hour]).mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File D:\Projetcs\lib\site-packages\pandas\core\groupby\groupby.py:1763, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1762 try:
# -> 1763     result = self.grouper._cython_operation(
#    1764         "aggregate",
#    1765         values,
#    1766         how,
#    1767         axis=data.ndim - 1,
#    1768         min_count=min_count,
#    1769         **kwargs,
#    1770     )
#    1771 except NotImplementedError:
#    1772     # generally if we have numeric_only=False
#    1773     # and non-applicable functions
#    1774     # try to python agg
#    1775     # TODO: shouldn't min_count matter?
#
# File D:\Projetcs\lib\site-packages\pandas\core\groupby\ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# ...

# %%
df7['values']=1
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8992\2377852081.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['values']=1

# %%
df7['LanduseTyp'].groupby([date_hk_col.hour])['values'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df7['LanduseTyp'].groupby([date_hk_col.hour])['values'].mean()
#
# File D:\Projetcs\lib\site-packages\pandas\core\base.py:248, in SelectionMixin.__getitem__(self, key)
#     246 else:
#     247     if key not in self.obj:
# --> 248         raise KeyError(f"Column not found: {key}")
#     249     subset = self.obj[key]
#     250     ndim = subset.ndim
#
# KeyError: 'Column not found: values'

# %%
df7.dtypes
# Out:
# LanduseTyp          category
# date_hk       datetime64[ns]
# values                 int64
# dtype: object

# %%
df7['LanduseTyp'].groupby([date_hk_col.hour],df7['values']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df7['LanduseTyp'].groupby([date_hk_col.hour],df7['values']).mean()
#
# File D:\Projetcs\lib\site-packages\pandas\core\series.py:2074, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    2072 if level is None and by is None:
#    2073     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 2074 axis = self._get_axis_number(axis)
#    2076 return SeriesGroupBy(
#    2077     obj=self,
#    2078     keys=by,
#    (...)
#    2086     dropna=dropna,
#    2087 )
#
# File D:\Projetcs\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     550 @final
#     551 @classmethod
#     552 def _get_axis_number(cls, axis: Axis) -> int:
#     553     try:
# --> 554         return cls._AXIS_TO_AXIS_NUMBER[axis]
# ...

# %%
df7['values'].groupby([date_hk_col.hour],df7['LanduseTyp']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df7['values'].groupby([date_hk_col.hour],df7['LanduseTyp']).mean()
#
# File D:\Projetcs\lib\site-packages\pandas\core\series.py:2074, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    2072 if level is None and by is None:
#    2073     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 2074 axis = self._get_axis_number(axis)
#    2076 return SeriesGroupBy(
#    2077     obj=self,
#    2078     keys=by,
#    (...)
#    2086     dropna=dropna,
#    2087 )
#
# File D:\Projetcs\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     550 @final
#     551 @classmethod
#     552 def _get_axis_number(cls, axis: Axis) -> int:
#     553     try:
# --> 554         return cls._AXIS_TO_AXIS_NUMBER[axis]
# ...

# %%
# by day(week day name)
df4['id_str_x'].groupby([df4['CreatedWW'],df4['LanduseTyp']]).count()
# Out:
# CreatedWW  LanduseTyp
# Friday     1               332
#            2              7256
#            3              8890
#            4              7356
#            5               336
#                          ...
# Wednesday  5               283
#            6                96
#            7              5278
#            8             10067
#            999           15038
# Name: id_str_x, Length: 63, dtype: int64

# %%
df4['id_str_x'].groupby([df4['CreatedWW'],df4['LanduseTyp']]).count().plot()
# Out:
# <AxesSubplot: xlabel='CreatedWW,LanduseTyp'>
